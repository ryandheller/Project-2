# %%
import pickle
import csv

times = 0
with open('ny_times_dict.pkl','rb') as handle:
    b = pickle.load(handle)
# for a in b:
#     for z in a:
        # print(z.get('title'))
        # times += 1
# print(times)
# print('break')
# print('break')
# print('break')
# print('break')

# with open('amazon_prices.csv') as csv_file:
#     csv_reader = csv.reader(csv_file, delimiter=',')
#     for row in csv_reader:
#         print(row[0])
amazon = 0
codeRed = 0
good_dicts = []
with open('amazon_prices1.pkl','rb') as handle:
    d = pickle.load(handle)
for a in b:
    for z in a:
        try:
            title = z.get('amazon_url').split('/')[3]
        except:
            'oh whale'
        for c in d:
            if c.get('Title') == title:
                z = {**c, **z}
                good_dicts.append(z)
                amazon += 1
            else:
                codeRed +=1
print(amazon, codeRed)
new_k = []
lol = 0
jk = 0
for k in good_dicts:
    new_k.append(k.get('amazon_url')) 
    # new_k.append(k.get('Title'))
print(len(new_k))
for a in b:
    for z in a:
        if z.get('amazon_url') in new_k:
            lol +=1
        else:
            good_dicts.append(z)
            jk +=1
print(lol, jk)
print(len(good_dicts))
kindle = []
for dicts in good_dicts:
    if 'Kindle' in dicts.keys():
        kindle.append(dicts['Kindle'])
    else:
        dicts['Kindle']=''
        kindle.append(dicts['Kindle'])
    if 'Hardcover' in dicts.keys():
        kindle.append(dicts['Hardcover'])
    else:
        dicts['Hardcover']=''
        kindle.append(dicts['Kindle'])
    if 'Paperback' in dicts.keys():
        kindle.append(dicts['Paperback'])
    else:
        dicts['Paperback']=''
        kindle.append(dicts['Kindle'])
    if 'Audio' in dicts.keys():
        kindle.append(dicts['Kindle'])
    else:
        dicts['Audio']=''
        kindle.append(dicts['Kindle'])
print(len(kindle),len(kindle)/4)
    
# print(times, amazon)
# import pymongo
# from pymongo import MongoClient

# client = MongoClient()
# db = client.NYT_best_sellers
# db.info.insert(good_dicts)
# Out:
# 6319 12335681
# 6319
# 6321 54
# 6373
# 6373

# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup
from requests_html import HTMLSession, user_agent
from tqdm import tqdm
import subprocess
from datetime import datetime, timedelta
import csv
import os
import glob
import numpy as np
import pickle
price_dict = []
def read_html_find_price(html_file):
    with open(html_file, 'r', encoding='utf-8') as f:
        soup = BeautifulSoup(f, "html.parser")
    try:
        prices = soup.find('ul', {"class": "a-unordered-list a-nostyle a-button-list a-horizontal"})\
        .find_all("span", {"class": "a-button-inner"})
    except Exception as e:
        print('no soup for u', e, html_file)
        prices = soup.find('ul', {"class": "a-tabs a-declarative"})\
        .find_all("span", {"class": "a-size-base mediaTab_subtitle"})
        
    results = {}
    strip_name = html_file.split('\\')[-1].strip()
    name = strip_name.split('.')[0].strip()
    for p in prices:
        if "Kindle" in p.get_text():
            resul = re.findall('\$\d{1,}\.\d{1,}', p.get_text())
            results['Kindle'] = resul[0].strip('[')
        elif "Hardcover" in p.get_text():
            resul = re.findall('\$\d{1,}\.\d{1,}', p.get_text())
            results['Hardcover'] = resul[0].strip('[')
        elif "Paperback" in p.get_text():
            resul = re.findall('\$\d{1,}\.\d{1,}', p.get_text())
            results['Paperback'] = resul[0].strip('[')
        elif "Audio" in p.get_text():
            resul = re.findall('\$\d{1,}\.\d{1,}', p.get_text())
            print(resul)
#             results['Audio'] = resul[0].strip('[')
        results['Title'] = name
#     strip_name = html_file.split('\\')[-1].strip()
#     name = strip_name.split('.')[0].strip()
#     results['Title'] = name
    price_dict.append(results)
    print(results)
    

existing_files = [x for x in glob.glob('htmlFolder/*.html')]
for files in existing_files:
    read_html_find_price(files)
    

print(price_dict)
# Out:
# ['$0.00']
# ['$20.81']
# {'Kindle': '$9.99', 'Title': '10th-Anniversary-Womens-Murder-Club', 'Hardcover': '$29.99', 'Paperback': '$8.87'}
# ['$0.00']
# {'Kindle': '$10.99', 'Title': '11-22-63-A-Novel', 'Hardcover': '$19.24', 'Paperback': '$2.73'}
# ['$0.00']
# ['$10.00']
# {'Kindle': '$3.99', 'Title': '113-Minutes-BookShots-James-Patterson-ebook', 'Paperback': '$4.99'}
# ['$0.00']
# ['$19.58']
# {'Kindle': '$9.99', 'Title': '11th-Hour-Womens-Murder-Club', 'Hardcover': '$13.89', 'Paperback': '$9.98'}
# ['$0.00']
# {'Kindle': '$6.99', 'Title': '1225-Christmas-Tree-Lane-Cedar', 'Hardcover': '$14.81', 'Paperback': '$5.99'}
# ['$0.00']
# ['$24.82']
# {'Kindle': '$9.99', 'Title': '12th-Never-Womens-Murder-Club', 'Hardcover': '$15.31', 'Paperback': '$9.83'}
# ['$0.00']
# {'Kindle': '$9.99', 'Title': '14th-Deadly-Womens-Murder-Club', 'Hardcover': '$11.54', 'Paperback': '$9.99'}
# ['$0.00']
# {'Kindle': '$9.99', 'Title': '15th-Affair-Womens-Murder-Club', 'Hardcover': '$15.69', 'Paperback': '$8.49'}
# ['$0.00']
# ['$18.21']
# {'Kindle': '$9.99', 'Title': '16th-Seduction-Womens-Murder-Club-ebook', 'Hardcover': '$16.83', 'Paperback': '$6.54'}
# ['$0.00']
# ['$23.63']
# {'Kindle': '$9.99', 'Title': '17th-Suspect-Womens-Murder-Club-ebook', 'Hardcover': '$12.49', 'Paperback': '$7.48'}
# ['$0.00']
# {'Kindle': '$12.99', 'Title': '1Q84-Haruki-Murakami-ebook', 'Hardcover': '$27.93', 'Paperback': '$16.20'}
# ['$0.00']
# ['$14.99']
# {'Kindle': '$8.99', 'Title': '44-Charles-Street-A-Novel', 'Hardcover': '$11.99', 'Paperback': '$7.05'}
# ['$0.00']
# ['$9.88']
# {'Kindle': '$11.99', 'Title': 'A-God-Ruins-Novel-ebook', 'Hardcover': '$19.91', 'Paperback': '$21.38'}
# ['$0.00']
# ['$12.78']
# {'Kindle': '$4.99', 'Title': 'A-Good-Marriage-Stephen-King-ebook'}
# ['$0.00']
# ['$53.16']
# {'Kindle': '$9.99', 'Title': 'A-Memory-Light-Wheel-Time-ebook', 'Hardcover': '$17.50', 'Paperback': '$8.99'}
# ['$0.00']
# ['$41.04']
# {'Kindle': '$6.99', 'Title': 'A-New-Hope-Thunder-Point', 'Hardcover': '$35.43', 'Paperback': '$7.41'}
# ['$0.00']
# {'Kindle': '$7.99', 'Title': 'A-Perfect-Life-Novel-ebook', 'Paperback': '$7.99'}
# ['$0.00']
# ['$26.25']
# {'Kindle': '$7.99', 'Title': 'A-Shiver-Light-Merry-Gentry', 'Hardcover': '$11.75', 'Paperback': '$7.19'}
# ['$0.00']
# {'Kindle': '$7.99', 'Title': 'A-Thousand-Tomorrows-Karen-Kingsbury-ebook', 'Hardcover': '$12.97', 'Paperback': '$8.00'}
# ['$0.00']
# ['$16.70']
# {'Kindle': '$8.99', 'Title': 'A-Week-Winter-Maeve-Binchy', 'Hardcover': '$16.85', 'Paperback': '$8.99'}
# ['$0.00']
# ['$31.98']
# {'Kindle': '$5.99', 'Title': 'A-Wicked-Snow-Gregg-Olsen-ebook', 'Hardcover': '$25.44', 'Paperback': '$7.99'}
# ['$0.00']
# {'Kindle': '$0.99', 'Title': 'Abbey-Ash-Rashid-Book-ebook', 'Paperback': '$9.99'}
# ['$0.00']
# {'Kindle': '$5.99', 'Title': 'About-That-Kiss-Heartbreaker-Novel-ebook', 'Hardcover': '$17.98', 'Paperback': '$6.79'}
# ['$0.00']
# ['$23.65']
# {'Kindle': '$0.00', 'Title': 'About-Vampire-An-Argeneau-Novel', 'Paperback': '$6.48'}
# ['$0.00']
# ['$14.69']
# {'Kindle': '$6.92', 'Title': 'Abraham-Lincoln-Vampire-Seth-Grahame-Smith', 'Paperback': '$7.95'}
# ['$0.00']
# ['$25.92']
# {'Kindle': '$12.99', 'Title': 'Absolutely-Remarkable-Thing-Novel', 'Hardcover': '$16.16', 'Paperback': '$16.00'}
# ['$0.00']
# ['$23.79']
# {'Kindle': '$8.99', 'Title': 'Accidental-Heroes-Novel-Danielle-Steel-ebook', 'Hardcover': '$17.20', 'Paperback': '$8.99'}
# ['$0.00']
# ['$18.87']
# {'Kindle': '$5.99', 'Title': 'Accidentally-Purpose-Heartbreaker-Bay-Novel-ebook', 'Hardcover': '$12.65', 'Paperback': '$6.79'}
# ['$0.00']
# ['$26.08']
# {'Kindle': '$8.99', 'Title': 'Accused-A-Rosato-Associates-Novel-ebook', 'Hardcover': '$10.48', 'Paperback': '$8.09'}
# ['$0.00']
# ['$21.97']
# {'Kindle': '$8.99', 'Title': 'Act-War-Thriller-Brad-Thor', 'Hardcover': '$7.39', 'Paperback': '$8.49'}
# ['$0.00']
# {'Kindle': '$4.99', 'Title': 'Addicted-An-Ethan-Frost-Novel-ebook'}
# ['$0.00']
# ['$4.00']
# {'Kindle': '$5.99', 'Title': 'Admission-Jean-Hanff-Korelitz-ebook', 'Hardcover': '$8.48', 'Paperback': '$11.50'}
# ['$0.00']
# {'Kindle': '$9.99', 'Title': 'Adultolescence-Gabbie-Hanna', 'Paperback': '$12.31'}
# {'Kindle': '$9.99', 'Title': 'Adventure-Zone-Here-There-Gerblins', 'Paperback': '$11.98'}
# ['$0.00']
# ['$17.99']
# {'Kindle': '$9.99', 'Title': 'Affair-bonus-short-story-Second-ebook', 'Hardcover': '$15.14', 'Paperback': '$7.49'}
# ['$0.00']
# ['$34.99']
# {'Kindle': '$7.99', 'Title': 'Affliction-Anita-Blake-Vampire-Hunter', 'Hardcover': '$12.98', 'Paperback': '$7.99'}
# ['$0.00']
# {'Kindle': '$3.99', 'Title': 'Aflame-A-Fall-Away-Novel-ebook'}
# ['$0.00']
# ['$31.26']
# {'Kindle': '$9.99', 'Title': 'After-Anna-Lisa-Scottoline-ebook', 'Hardcover': '$11.82', 'Paperback': '$8.19'}
# ['$0.00']
# {'Kindle': '$10.99', 'Title': 'After-Dead-World-Sookie-Stackhouse-ebook', 'Hardcover': '$20.00', 'Paperback': '$14.15'}
# ['$0.00']
# {'Kindle': '$7.99', 'Title': 'After-Storm-A-KGI-Novel-ebook', 'Paperback': '$6.39'}
# ['$0.00']
# ['$17.99']
# {'Kindle': '$11.99', 'Title': 'After-You-Novel-Jojo-Moyes', 'Hardcover': '$11.36', 'Paperback': '$9.67'}
# ['$0.00']
# ['$23.99']
# {'Kindle': '$9.99', 'Title': 'Aftermath-Star-Journey-Force-Awakens', 'Hardcover': '$15.39', 'Paperback': '$8.49'}
# ['$0.00']
# {'Kindle': '$9.99', 'Title': 'Against-All-Enemies-Tom-Clancy', 'Hardcover': '$11.00', 'Paperback': '$11.34'}
# ['$0.00']
# ['$21.46']
# {'Kindle': '$8.99', 'Title': 'Against-All-Odds-Danielle-Steel-ebook', 'Hardcover': '$11.36', 'Paperback': '$8.79'}
# ['$0.00']
# []
# {'Kindle': '$5.99', 'Title': 'Against-Tide-Brodies-Alaska-Book-ebook', 'Hardcover': '$84.99', 'Paperback': '$7.99'}
# ['$0.00']
# ['$14.97']
# {'Kindle': '$9.49', 'Title': 'Agenda-21-Glenn-Beck-ebook', 'Hardcover': '$13.58', 'Paperback': '$9.99'}
# ['$0.00']
# {'Kindle': '$9.99', 'Title': 'Agent-Place-Gray-Mark-Greaney-ebook', 'Hardcover': '$18.93', 'Paperback': '$6.76'}
# ['$0.00']
# ['$17.56']
# {'Kindle': '$7.99', 'Title': 'Aint-Sweet-Green-Mountain-Romance-ebook', 'Paperback': '$7.19'}
# ['$0.00']
# []
# {'Kindle': '$8.99', 'Title': 'Air-Bound-Sea-Haven-Novel-ebook', 'Hardcover': '$5.25', 'Paperback': '$7.99'}
# ['$0.00']
# ['$19.85']
# {'Kindle': '$10.99', 'Title': 'Alaskan-Holiday-Novel-Debbie-Macomber-ebook', 'Hardcover': '$12.25', 'Paperback': '$14.58'}
# ['$0.00']
# ['$15.71']
# {'Kindle': '$11.99', 'Title': 'Alchemist-Paulo-Coelho', 'Hardcover': '$18.99', 'Paperback': '$19.98'}
# ['$0.00']
# ['$20.00']
# {'Kindle': '$9.99', 'Title': 'Alert-Michael-Bennett-James-Patterson', 'Hardcover': '$16.98', 'Paperback': '$8.49'}
# ['$0.00']
# ['$32.12']
# {'Kindle': '$9.99', 'Title': 'Alex-Cross-Run-James-Patterson-ebook', 'Hardcover': '$18.99', 'Paperback': '$8.50'}
# ['$0.00']
# ['$13.77']
# {'Kindle': '$8.99', 'Title': 'Alibi-Kinsey-Millhone-Alphabet-Mysteries-ebook', 'Hardcover': '$21.83', 'Paperback': '$7.19'}
# ['$0.00']
# {'Kindle': '$11.99', 'Title': 'Alice-Network-Novel-Kate-Quinn-ebook', 'Hardcover': '$29.36', 'Paperback': '$11.24'}
# ['$0.00']
# ['$12.25']
# {'Kindle': '$7.99', 'Title': 'All-Dressed-White-Under-Suspicion-ebook', 'Hardcover': '$37.04', 'Paperback': '$7.99'}
# ['$0.00']
# {'Kindle': '$5.99', 'Title': 'All-Ever-Need-Sullivans-Book-ebook', 'Paperback': '$14.99'}
# ['$0.00']
# ['$14.13']
# {'Kindle': '$12.99', 'Title': 'All-Fall-Down-A-Novel-ebook', 'Hardcover': '$11.97', 'Paperback': '$9.25'}
# ['$0.00']
# ['$11.69']
# {'Kindle': '$9.99', 'Title': 'All-Girl-Filling-Stations-Last-Reunion-ebook', 'Hardcover': '$9.72', 'Paperback': '$9.83'}
# ['$0.00']
# ['$16.94']
# {'Kindle': '$12.99', 'Title': 'All-Light-We-Cannot-See', 'Hardcover': '$15.33', 'Paperback': '$13.60'}
# ['$0.00']
# ['$19.99']
# {'Kindle': '$11.49', 'Title': 'All-Single-Ladies-A-Novel-ebook', 'Hardcover': '$13.99', 'Paperback': '$13.66'}
# ['$0.00']
# {'Kindle': '$5.99', 'Title': 'All-Summer-Long-Susan-Mallery-ebook', 'Hardcover': '$3.95', 'Paperback': '$7.99'}
# ['$0.00']
# ['$28.62']
# {'Kindle': '$14.99', 'Title': 'All-We-Ever-Wanted-Novel-ebook', 'Hardcover': '$18.67', 'Paperback': '$11.59'}
# ['$0.00']
# {'Kindle': '$3.99', 'Title': 'All-You-Need-Is-Love-ebook', 'Paperback': '$6.79'}
# ['$0.00']
# ['$27.18']
# {'Kindle': '$9.99', 'Title': 'All-Your-Perfects-Colleen-Hoover-ebook', 'Hardcover': '$13.49', 'Paperback': '$8.80'}
# ['$0.00']
# ['$43.42']
# {'Kindle': '$7.99', 'Title': 'Alone-Detective-D-Warren-Novel-ebook', 'Hardcover': '$20.51', 'Paperback': '$7.19'}
# ['$0.00']
# {'Kindle': '$0.00', 'Title': 'Alpha-Jasinda-Wilder-ebook', 'Hardcover': '$16.99', 'Paperback': '$15.69'}
# ['$0.00']
# []
# {'Kindle': '$6.99', 'Title': 'Always-Cowboy-Carsons-Mustang-Creek-ebook', 'Hardcover': '$37.99', 'Paperback': '$6.79'}
# ['$0.00']
# ['$23.31']
# {'Kindle': '$7.99', 'Title': 'Always-Mind-Lucky-Harbor-Novel', 'Paperback': '$6.80'}
# ['$0.00']
# ['$23.00']
# {'Kindle': '$14.99', 'Title': 'Ambush-Michael-Bennett-Book-11-ebook', 'Hardcover': '$15.78', 'Paperback': '$16.99'}
# ['$0.00']
# ['$13.77']
# {'Kindle': '$8.99', 'Title': 'American-Assassin-Thriller-Mitch-Rapp-ebook', 'Hardcover': '$14.28', 'Paperback': '$7.26'}
# ['$0.00']
# {'Kindle': '$9.99', 'Title': 'American-Gods-Tenth-Anniversary-Edition-ebook', 'Hardcover': '$18.10', 'Paperback': '$8.49'}
# ['$0.00']
# ['$23.79']
# {'Kindle': '$9.58', 'Title': 'American-Marriage-Novel-Oprahs-Selection-ebook', 'Hardcover': '$11.28', 'Paperback': '$10.91'}
# ['$0.00']
# ['$26.99']
# {'Kindle': '$7.99', 'Title': 'Among-Wicked-Kate-Burkholder-Novel-ebook', 'Hardcover': '$13.49', 'Paperback': '$7.19'}
# ['$0.00']
# ['$21.03']
# {'Kindle': '$12.99', 'Title': 'And-Mountains-Echoed-Khaled-Hosseini', 'Hardcover': '$16.00', 'Paperback': '$8.00'}
# ['$0.00']
